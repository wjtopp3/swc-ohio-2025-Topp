# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![WorkingConnections-logo.png](data:image/png;base64,...)

# %% [markdown]
# # Summer Working Connections 2025
# ## Columbus State Community College, Ohio

# %% [markdown]
# #Secure Programming with Python Assessment
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Profs. Pamela Brauda and David Singletary
# ### Florida State College at Jacksonville

# %% [markdown]
# This assessment has multiple steps. Please attempt as many as possible.

# %% [markdown]
# # Task 1 - Set Up a Private GitHub Repo for a Python Project
#
# ---
#
# a. Go to [https://github.com](https://github.com) and log in.
# b. Click the **+** icon in the top-right corner and choose **New repository**.
# c. Fill in:
#    - Repository name: `swc-ohio-2025-#lastName#
#      (Please change #lastName# to YOUR last name)
#
#    - Description (optional)
#
# d. Under **Visibility**, select **Private**.
# e. Check **"Add a README file"**.
# f. Click **Create repository**.
# g. Edit the README.md file: add your name, email, college, date
# h. Invite your instructors to collaborate in your repo:
#   - ProfBrauda
#   - ProfSingletary
# ---

# %% [markdown]
# # Task 2 - Write a python program that:
# 1. Tracks failed login attempts for multiple users
#   - See Day 1 - Hands On: Using defaultDict(int) to Count Things
# 2. Locks out a user after too many failed attempts and logs the lockout event to a file, encrypting the user name
#   - See Day 1 - Hands On: Secure Login Handling with Account Lockout and Event Logging
#   - See Day 3 - Hands On: Manage a Symmetric Encryption Key Using Fernet
#
# 4. Uses secure and maintainable coding practices(e.g., no bare except, use defaultdict, use safe dictionary access)

# %% [markdown]
# Expected output:
#
# ```
# Login Attempt Summary:
# alice: 3 attempt(s)
# bob: 3 attempt(s)
# charlie: 1 attempt(s)
# david: 3 attempt(s)
# ```
#
# There will also be a text file named security_log.txt and a key file named furnet.key

# %% [markdown]
# Use the following 'skeleton' code to help get started. The comments suggest what code should go where.
# Be mindful of indentation! Be consistent so your code will run.

# %%
from collections import defaultdict
from datetime import datetime
import logging
from cryptography.fernet import Fernet
import os

# Constants
MAX_ATTEMPTS = 3
LOG_FILE = "security_log.txt"
DKEY_FILE = "fernet.key"

# Initialize defaultdict with int — default value is 0
login_attempts = defaultdict(int)

# Simulated login attempts (from user input or logs)
attempts = ["alice", "bob", "alice", "david", "alice", "bob", "charlie", "david", "bob", "david"]



# Generate and store a key if it doesn't already exist

key = Fernet.generate_key()
with open(DKEY_FILE, "wb") as key_file:
    key_file.write(key)

# To use the key later, read it back securely and initialize the cipher object:

# Load the key
#with open(DKEY_FILE, "rb") as key_file:
#    key = key_file.read()

#cipher = Fernet(key)

# Configure logging
#	Configure the logger to write ERROR level messages to "security_log.txt" using
#    2025-05-12	10:42:31 - ERROR - User '#encryptedName#' has been locked out after 3 failed attempts.

# Track who is already locked to avoid duplicate log entries
num_locked = 0
locked_users = set()

# Simulated login attempts (can be randomized or expanded)
# security_log.txt will contain lockout entries
def log_event(message):
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    with open(LOG_FILE, "a") as f:
        f.write(f"[{timestamp}] {message}\n")


# Track failed attempts using defaultdict(int)
# Process login attempts
for user in attempts:
    print("in loop",user)
    login_attempts[user] += 1

    if login_attempts[user] <= MAX_ATTEMPTS and user not in locked_users:
        try:
            print(f"{user} logged in successfully.")
            #login_attempts[user] = 0  # Reset on success
            encrypted_user = "*******"
            log_event(f"{encrypted_user} logged in successfully.")

        except OSError as e:
            login_attempts[user] += 1
            log_event(f"Failed login attempt for {user} ({login_attempts[user]})")

            if login_attempts[user] >= MAX_ATTEMPTS:
                print(f"{user} has been locked out after {MAX_ATTEMPTS} failed attempts.")
                log_event(f"LOCKOUT: {timestamp} - ERROR - {user} locked out after {MAX_ATTEMPTS} failed attempts.")
                print(f"***Account for '{user}' is locked!***")
                log_event(f"LOCKOUT: {user} attempted login while locked.")
                locked_users.add = user
                num_locked += 1
            print(f"Logging failed: {e}")

# Print summary of all users and their attempt count
print("")
print(login_attempts)
print("Login Attempt Summary:")
for user, count in login_attempts.items():
    print(f"{user}: {count} attempt(s)") #user is in plain text here
# Out:
# in loop alice
# alice logged in successfully.
# in loop bob
# bob logged in successfully.
# in loop alice
# alice logged in successfully.
# in loop david
# david logged in successfully.
# in loop alice
# alice logged in successfully.
# in loop bob
# bob logged in successfully.
# in loop charlie
# charlie logged in successfully.
# in loop david
# david logged in successfully.
# in loop bob
# bob logged in successfully.
# in loop david
# david logged in successfully.
#
# defaultdict(<class 'int'>, {'alice': 3, 'bob': 3, 'david': 3, 'charlie': 1})
# Login Attempt Summary:
# alice: 3 attempt(s)
# bob: 3 attempt(s)
# david: 3 attempt(s)
# charlie: 1 attempt(s)

# %% [markdown]
# # Task 3 - Show us it works!
# Demo your program for one of your instructors. Generous partial credit is awarded for serious attempts!

# %% [markdown]
# #Task 4 - Save and submit!
# - Save your notebook
#   - File -> Save
# - Download your notebook as .ipynb
#   - File -> Download -> .ipynb
# - Upload your notebook to your github repo

# %% [markdown]
# # Thank you!
#
# It was our pleasure to present this short course to you! We appreciate your patience, your attention, your questions, and your collaboration. We look forward to working with you in the future.
#
# Hope to see you at [HI-TEC 2025](https://www.highimpact-tec.org/) in Minneapolis!
